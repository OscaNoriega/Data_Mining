# %%
# LIBRERIAS BASE

from google.colab import files
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# FUNCIONES

def calculate_vif_(X):
    variables = list(range(X.shape[1]))
    vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]
    print(X.columns[variables])
    return vif

# %%
#DATA LOADING & PREVIEW

url = 'https://raw.githubusercontent.com/OscarNoriega/Data_Mining/main/base_final.csv'
df = pd.read_csv(url,sep=';')
df.head()
# Out:
#       ID  Year_Birth   Education  ... Response  Complain  Country
# 0   1826        1970  Graduation  ...        1         0       SP
# 1      1        1961  Graduation  ...        1         0    Other
# 2  10476        1958  Graduation  ...        0         0    Other
# 3   1386        1967  Graduation  ...        0         0    Other
# 4   5371        1989  Graduation  ...        1         0       SP
#
# [5 rows x 27 columns]

# %%
#DATA PREPARATION (VERY IMPORTANT TO DIFFERENTIATE "X" AND "DF")

X = df.drop(columns=['ID','AcceptedCmp1','AcceptedCmp2','AcceptedCmp3','Complain','Year_Birth','NumDealsPurchases','NumWebVisitsMonth'])  # PRIMERO ELIMINAR VARIABLES QUE NO VAN A IR EN EL ALGORITMO
X = pd.get_dummies(X)  # ACA SE CREAN DUMMIES (EN CASO HAYA ALGUNA VARIABLE CATEGORICA, SI NO HAY NO CREARA NADA)
X.head()
# Out:
#     Income   Kidhome  ...  Country_Other  Country_SP
# 0     84835        0  ...              0           1
# 1     57091        0  ...              1           0
# 2     67267        0  ...              1           0
# 3     32474        1  ...              1           0
# 4     21474        1  ...              0           1
#
# [5 rows x 24 columns]

# %%
X = X.drop(columns=['Kidhome','Recency','MntGoldProds','NumWebPurchases','Education_Basic'])   # EN CASO ESTEMOS CREANDO DUMMIES PARA CATEGORICAS SIEMPRE ELIMINAR 1 DE LAS N OPCIONES QUE SE CREAN (SOLO QUEDARIAN N-1 FLAGS POR CADA CATEGORICA)
X.head()
# Out:
#     Income   Teenhome  ...  Country_Other  Country_SP
# 0     84835         0  ...              0           1
# 1     57091         0  ...              1           0
# 2     67267         1  ...              1           0
# 3     32474         1  ...              1           0
# 4     21474         0  ...              0           1
#
# [5 rows x 19 columns]

# %%
# ALGORITHM FIT

dep = ' Income '  # ACA SOLO MODIFICAR LA VARIABLE DEPENDIENTE "dep", DEJAR TODO LO DEMAS IGUAL

mod = sm.OLS(X[dep], sm.add_constant(X.drop(columns=[dep])))    
res = mod.fit()
print(res.summary())
print('')
print('')
print('')
print('VIF RESULTS')
print('')
calculate_vif_(X.drop(columns=[dep]))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Income    R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     136.4
# Date:                Wed, 10 Mar 2021   Prob (F-statistic):          2.18e-314
# Time:                        03:56:15   Log-Likelihood:                -24825.
# No. Observations:                2215   AIC:                         4.968e+04
# Df Residuals:                    2198   BIC:                         4.978e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     1.21e+04    668.823     18.091      0.000    1.08e+04    1.34e+04
# ...
